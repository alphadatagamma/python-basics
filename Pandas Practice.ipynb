# %% [markdown]
# ## Pandas practice notebook

# %%
## Pandas practice notebook
import pandas as pd
import numpy as np

# %%
# Reading a dataset
data = pd.read_csv("train.csv")
data.head(6)
# Out:
#    Id  MSSubClass MSZoning  \
# 0   1          60       RL
# 1   2          20       RL
# 2   3          60       RL
# 3   4          70       RL
# 4   5          60       RL
# 5   6          50       RL
#
#    LotFrontage  LotArea Street Alley  \
# 0         65.0     8450   Pave   NaN
# 1         80.0     9600   Pave   NaN
# 2         68.0    11250   Pave   NaN
# 3         60.0     9550   Pave   NaN
# 4         84.0    14260   Pave   NaN
# 5         85.0    14115   Pave   NaN
#
#   LotShape LandContour Utilities  ...  \
# 0      Reg         Lvl    AllPub  ...
# 1      Reg         Lvl    AllPub  ...
# 2      IR1         Lvl    AllPub  ...
# 3      IR1         Lvl    AllPub  ...
# 4      IR1         Lvl    AllPub  ...
# 5      IR1         Lvl    AllPub  ...
#
#   PoolArea PoolQC  Fence MiscFeature  \
# 0        0    NaN    NaN         NaN
# 1        0    NaN    NaN         NaN
# 2        0    NaN    NaN         NaN
# 3        0    NaN    NaN         NaN
# 4        0    NaN    NaN         NaN
# 5        0    NaN  MnPrv        Shed
#
#   MiscVal MoSold YrSold  SaleType  \
# 0       0      2   2008        WD
# 1       0      5   2007        WD
# 2       0      9   2008        WD
# 3       0      2   2006        WD
# 4       0     12   2008        WD
# 5     700     10   2009        WD
#
#    SaleCondition  SalePrice
# 0         Normal     208500
# 1         Normal     181500
# 2         Normal     223500
# 3        Abnorml     140000
# 4         Normal     250000
# 5         Normal     143000
#
# [6 rows x 81 columns]

# %% [markdown]
# #### Creating a series from various objects

# %%
series1 = pd.Series(data.Id[0:5])
dic  = {'a':'abhi', 'r':'ritika'}
series2 = pd.Series(dic, index=['b', 'c','r', 'd', 'a'])

arr = np.array([1, 2, 3])
series3 = pd.Series(arr)

print('series1')
print(series1)
print('series2')
print(series2)
print('series3')
print(series3)
# Out:
# series1
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Id, dtype: int64
# series2
# b       NaN
# c       NaN
# r    ritika
# d       NaN
# a      abhi
# dtype: object
# series3
# 0    1
# 1    2
# 2    3
# dtype: int32

# %% [markdown]
# ### NaN (not a number) is the standard missing data marker used in pandas.

# %% [markdown]
# #### .dtype is used to find datatypes of a series or variable or dataframes columns

# %%
series3.dtype
# Out:
# dtype('int32')

# %%
print(data.Id.dtype)
print(data.Alley.dtype)
# Out:
# int64
# object

# %% [markdown]
# #### datatype of String is objects

# %% [markdown]
# ### Series Operations

# %% [markdown]
# #### Series have a name attribute

# %%
s1 = pd.Series([1,2,3,4,5], name = 'abhi')
s2 = pd.Series([5,4,3,2,1], name = 'riti')
print(s1.name)
print(s2.name)
print(s1+s2)
print(s1-s2)

# e raised to power elements in series
print(np.exp(s1))

# Missing values in operation make Nan
print(s1[1:]+s2[:-1])
# Out:
# abhi
# riti
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# dtype: int64
# 0   -4
# 1   -2
# 2    0
# 3    2
# 4    4
# dtype: int64
# 0      2.718282
# 1      7.389056
# 2     20.085537
# 3     54.598150
# 4    148.413159
# Name: abhi, dtype: float64
# 0    NaN
# 1    6.0
# 2    6.0
# 3    6.0
# 4    NaN
# dtype: float64

# %% [markdown]
# ### DataFrames
#
# DataFrame accepts many different kinds of input:
#
# - Dict of 1D ndarrays, lists, dicts, or Series
# - 2-D numpy.ndarray
# - Structured or record ndarray
# - A Series
# - Another DataFrame

# %%
dic = {'name':['abhi', 'riti'], 'gender':['male', 'female']}
print(pd.DataFrame(dic))
print(' ')
dic = {'name':{1: 'abhi',2: 'riti'}, 'gender':{1:'male', 2:'female'}}
print(pd.DataFrame(dic))
print(' ')
arr = np.array([[1, 2, 3],[4,5,6]])
print(pd.DataFrame(arr,columns =['a','b','c'], index = [1,2]))
print(' ')
print(data[1:3])
# Out:
#    name  gender
# 0  abhi    male
# 1  riti  female
#
#    name  gender
# 1  abhi    male
# 2  riti  female
#
#    a  b  c
# 1  1  2  3
# 2  4  5  6
#
#    Id  MSSubClass MSZoning  \
# 1   2          20       RL
# 2   3          60       RL
#
#    LotFrontage  LotArea Street Alley  \
# 1         80.0     9600   Pave   NaN
# 2         68.0    11250   Pave   NaN
#
#   LotShape LandContour Utilities  ...  \
# 1      Reg         Lvl    AllPub  ...
# 2      IR1         Lvl    AllPub  ...
#
#   PoolArea PoolQC Fence MiscFeature  \
# 1        0    NaN   NaN         NaN
# 2        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  \
# 1       0      5   2007        WD
# 2       0      9   2008        WD
#
#    SaleCondition  SalePrice
# 1         Normal     181500
# 2         Normal     223500
#
# [2 rows x 81 columns]

# %% [markdown]
# ### Column selection, addition and deletion

# %%
data1= data['Id'][:5]
data1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Id, dtype: int64

# %%
#data.pop('Id')
data['Id2'] = data.Id+1
data
# Out:
#         Id  MSSubClass MSZoning  \
# 0        1          60       RL
# 1        2          20       RL
# 2        3          60       RL
# 3        4          70       RL
# 4        5          60       RL
# ...    ...         ...      ...
# 1455  1456          60       RL
# 1456  1457          20       RL
# 1457  1458          70       RL
# 1458  1459          20       RL
# 1459  1460          20       RL
#
#       LotFrontage  LotArea Street  \
# 0            65.0     8450   Pave
# 1            80.0     9600   Pave
# 2            68.0    11250   Pave
# 3            60.0     9550   Pave
# 4            84.0    14260   Pave
# ...           ...      ...    ...
# 1455         62.0     7917   Pave
# 1456         85.0    13175   Pave
# 1457         66.0     9042   Pave
# 1458         68.0     9717   Pave
# 1459         75.0     9937   Pave
#
#      Alley LotShape LandContour  \
# 0      NaN      Reg         Lvl
# 1      NaN      Reg         Lvl
# 2      NaN      IR1         Lvl
# 3      NaN      IR1         Lvl
# 4      NaN      IR1         Lvl
# ...    ...      ...         ...
# 1455   NaN      Reg         Lvl
# 1456   NaN      Reg         Lvl
# 1457   NaN      Reg         Lvl
# 1458   NaN      Reg         Lvl
# 1459   NaN      Reg         Lvl
#
#      Utilities  ... PoolQC  Fence  \
# 0       AllPub  ...    NaN    NaN
# 1       AllPub  ...    NaN    NaN
# 2       AllPub  ...    NaN    NaN
# 3       AllPub  ...    NaN    NaN
# 4       AllPub  ...    NaN    NaN
# ...        ...  ...    ...    ...
# 1455    AllPub  ...    NaN    NaN
# 1456    AllPub  ...    NaN  MnPrv
# 1457    AllPub  ...    NaN  GdPrv
# 1458    AllPub  ...    NaN    NaN
# 1459    AllPub  ...    NaN    NaN
#
#      MiscFeature MiscVal MoSold  \
# 0            NaN       0      2
# 1            NaN       0      5
# 2            NaN       0      9
# 3            NaN       0      2
# 4            NaN       0     12
# ...          ...     ...    ...
# 1455         NaN       0      8
# 1456         NaN       0      2
# 1457        Shed    2500      5
# 1458         NaN       0      4
# 1459         NaN       0      6
#
#      YrSold SaleType  SaleCondition  \
# 0      2008       WD         Normal
# 1      2007       WD         Normal
# 2      2008       WD         Normal
# 3      2006       WD        Abnorml
# 4      2008       WD         Normal
# ...     ...      ...            ...
# 1455   2007       WD         Normal
# 1456   2010       WD         Normal
# 1457   2010       WD         Normal
# 1458   2010       WD         Normal
# 1459   2008       WD         Normal
#
#       SalePrice   Id2
# 0        208500     2
# 1        181500     3
# 2        223500     4
# 3        140000     5
# 4        250000     6
# ...         ...   ...
# 1455     175000  1457
# 1456     210000  1458
# 1457     266500  1459
# 1458     142125  1460
# 1459     147500  1461
#
# [1460 rows x 82 columns]

# %%
data.assign(ID2=lambda x: (x['Id']+2 )).head()
# Out:
#    Id  MSSubClass MSZoning  \
# 0   1          60       RL
# 1   2          20       RL
# 2   3          60       RL
# 3   4          70       RL
# 4   5          60       RL
#
#    LotFrontage  LotArea Street Alley  \
# 0         65.0     8450   Pave   NaN
# 1         80.0     9600   Pave   NaN
# 2         68.0    11250   Pave   NaN
# 3         60.0     9550   Pave   NaN
# 4         84.0    14260   Pave   NaN
#
#   LotShape LandContour Utilities  ...  \
# 0      Reg         Lvl    AllPub  ...
# 1      Reg         Lvl    AllPub  ...
# 2      IR1         Lvl    AllPub  ...
# 3      IR1         Lvl    AllPub  ...
# 4      IR1         Lvl    AllPub  ...
#
#   Fence MiscFeature MiscVal MoSold  \
# 0   NaN         NaN       0      2
# 1   NaN         NaN       0      5
# 2   NaN         NaN       0      9
# 3   NaN         NaN       0      2
# 4   NaN         NaN       0     12
#
#   YrSold SaleType SaleCondition  \
# 0   2008       WD        Normal
# 1   2007       WD        Normal
# 2   2008       WD        Normal
# 3   2006       WD       Abnorml
# 4   2008       WD        Normal
#
#    SalePrice  Id2  ID2
# 0     208500    2    3
# 1     181500    3    4
# 2     223500    4    5
# 3     140000    5    6
# 4     250000    6    7
#
# [5 rows x 83 columns]

# %% [markdown]
# ### Indexing and Selection

# %%
data[1:3]
# Out:
#    Id  MSSubClass MSZoning  \
# 1   2          20       RL
# 2   3          60       RL
#
#    LotFrontage  LotArea Street Alley  \
# 1         80.0     9600   Pave   NaN
# 2         68.0    11250   Pave   NaN
#
#   LotShape LandContour Utilities  ...  \
# 1      Reg         Lvl    AllPub  ...
# 2      IR1         Lvl    AllPub  ...
#
#   PoolQC Fence MiscFeature MiscVal  \
# 1    NaN   NaN         NaN       0
# 2    NaN   NaN         NaN       0
#
#   MoSold YrSold SaleType  \
# 1      5   2007       WD
# 2      9   2008       WD
#
#    SaleCondition  SalePrice  Id2
# 1         Normal     181500    3
# 2         Normal     223500    4
#
# [2 rows x 82 columns]

# %%
data['LotShape'][11:13] ##returns series
# Out:
# 11    IR1
# 12    IR2
# Name: LotShape, dtype: object

# %%
data[2:3]
# Out:
#    Id  MSSubClass MSZoning  \
# 2   3          60       RL
#
#    LotFrontage  LotArea Street Alley  \
# 2         68.0    11250   Pave   NaN
#
#   LotShape LandContour Utilities  ...  \
# 2      IR1         Lvl    AllPub  ...
#
#   PoolQC Fence MiscFeature MiscVal  \
# 2    NaN   NaN         NaN       0
#
#   MoSold YrSold SaleType  \
# 2      9   2008       WD
#
#    SaleCondition  SalePrice  Id2
# 2         Normal     223500    4
#
# [1 rows x 82 columns]

# %%
data[['Id','Alley']][2:4]
# Out:
#    Id Alley
# 2   3   NaN
# 3   4   NaN

# %%
#creating a filter
filtr = (data.Id == 2)

# %%
data[filtr]
# Out:
#    Id  MSSubClass MSZoning  \
# 1   2          20       RL
#
#    LotFrontage  LotArea Street Alley  \
# 1         80.0     9600   Pave   NaN
#
#   LotShape LandContour Utilities  ...  \
# 1      Reg         Lvl    AllPub  ...
#
#   PoolQC Fence MiscFeature MiscVal  \
# 1    NaN   NaN         NaN       0
#
#   MoSold YrSold SaleType  \
# 1      5   2007       WD
#
#    SaleCondition  SalePrice  Id2
# 1         Normal     181500    3
#
# [1 rows x 82 columns]

# %%
### Based on row and column location
data.iloc[[0,1,2,3],[0,1,2,4,5]]
# Out:
#    Id  MSSubClass MSZoning  LotArea  \
# 0   1          60       RL     8450
# 1   2          20       RL     9600
# 2   3          60       RL    11250
# 3   4          70       RL     9550
#
#   Street
# 0   Pave
# 1   Pave
# 2   Pave
# 3   Pave

# %%
data.loc[0:3,'Id':'Alley']
# Out:
#    Id  MSSubClass MSZoning  \
# 0   1          60       RL
# 1   2          20       RL
# 2   3          60       RL
# 3   4          70       RL
#
#    LotFrontage  LotArea Street Alley
# 0         65.0     8450   Pave   NaN
# 1         80.0     9600   Pave   NaN
# 2         68.0    11250   Pave   NaN
# 3         60.0     9550   Pave   NaN

# %%
data.loc[data.Id%2==0,'Id':'Alley'][:6]
# Out:
#     Id  MSSubClass MSZoning  \
# 1    2          20       RL
# 3    4          70       RL
# 5    6          50       RL
# 7    8          60       RL
# 9   10         190       RL
# 11  12          60       RL
#
#     LotFrontage  LotArea Street Alley
# 1          80.0     9600   Pave   NaN
# 3          60.0     9550   Pave   NaN
# 5          85.0    14115   Pave   NaN
# 7           NaN    10382   Pave   NaN
# 9          50.0     7420   Pave   NaN
# 11         85.0    11924   Pave   NaN

# %%
data.loc[data.Id%2==0,'MSSubClass':'Alley'] = np.nan
data
# Out:
#         Id MSSubClass MSZoning  \
# 0        1         60       RL
# 1        2        NaN      NaN
# 2        3         60       RL
# 3        4        NaN      NaN
# 4        5         60       RL
# ...    ...        ...      ...
# 1455  1456        NaN      NaN
# 1456  1457         20       RL
# 1457  1458        NaN      NaN
# 1458  1459         20       RL
# 1459  1460        NaN      NaN
#
#      LotFrontage LotArea Street Alley  \
# 0             65    8450   Pave   NaN
# 1            NaN     NaN    NaN   NaN
# 2             68   11250   Pave   NaN
# 3            NaN     NaN    NaN   NaN
# 4             84   14260   Pave   NaN
# ...          ...     ...    ...   ...
# 1455         NaN     NaN    NaN   NaN
# 1456          85   13175   Pave   NaN
# 1457         NaN     NaN    NaN   NaN
# 1458          68    9717   Pave   NaN
# 1459         NaN     NaN    NaN   NaN
#
#      LotShape LandContour Utilities  \
# 0         Reg         Lvl    AllPub
# 1         Reg         Lvl    AllPub
# 2         IR1         Lvl    AllPub
# 3         IR1         Lvl    AllPub
# 4         IR1         Lvl    AllPub
# ...       ...         ...       ...
# 1455      Reg         Lvl    AllPub
# 1456      Reg         Lvl    AllPub
# 1457      Reg         Lvl    AllPub
# 1458      Reg         Lvl    AllPub
# 1459      Reg         Lvl    AllPub
#
#       ... PoolQC  Fence MiscFeature  \
# 0     ...    NaN    NaN         NaN
# 1     ...    NaN    NaN         NaN
# 2     ...    NaN    NaN         NaN
# 3     ...    NaN    NaN         NaN
# 4     ...    NaN    NaN         NaN
# ...   ...    ...    ...         ...
# 1455  ...    NaN    NaN         NaN
# 1456  ...    NaN  MnPrv         NaN
# 1457  ...    NaN  GdPrv        Shed
# 1458  ...    NaN    NaN         NaN
# 1459  ...    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold SaleType  \
# 0          0      2   2008       WD
# 1          0      5   2007       WD
# 2          0      9   2008       WD
# 3          0      2   2006       WD
# 4          0     12   2008       WD
# ...      ...    ...    ...      ...
# 1455       0      8   2007       WD
# 1456       0      2   2010       WD
# 1457    2500      5   2010       WD
# 1458       0      4   2010       WD
# 1459       0      6   2008       WD
#
#       SaleCondition  SalePrice   Id2
# 0            Normal     208500     2
# 1            Normal     181500     3
# 2            Normal     223500     4
# 3           Abnorml     140000     5
# 4            Normal     250000     6
# ...             ...        ...   ...
# 1455         Normal     175000  1457
# 1456         Normal     210000  1458
# 1457         Normal     266500  1459
# 1458         Normal     142125  1460
# 1459         Normal     147500  1461
#
# [1460 rows x 82 columns]

# %% [markdown]
# ### Transposing

# %%
data.loc[1:3,'Id':'MSZoning'].T
# Out:
#               1   2    3
# Id            2   3    4
# MSSubClass  NaN  60  NaN
# MSZoning    NaN  RL  NaN

# %%
data.iloc[:,[2,3,4,5]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MSZoning     1460 non-null   object
#  1   LotFrontage  1326 non-null   object
#  2   LotArea      1460 non-null   object
#  3   Street       1460 non-null   object
# dtypes: object(4)
# memory usage: 45.8+ KB

# %%
pd.set_option('display.width', 40)
data
# Out:
#         Id MSSubClass MSZoning  \
# 0        1         60       RL
# 1        2        NaN      NaN
# 2        3         60       RL
# 3        4        NaN      NaN
# 4        5         60       RL
# ...    ...        ...      ...
# 1455  1456        NaN      NaN
# 1456  1457         20       RL
# 1457  1458        NaN      NaN
# 1458  1459         20       RL
# 1459  1460        NaN      NaN
#
#      LotFrontage LotArea Street Alley  \
# 0             65    8450   Pave   NaN
# 1            NaN     NaN    NaN   NaN
# 2             68   11250   Pave   NaN
# 3            NaN     NaN    NaN   NaN
# 4             84   14260   Pave   NaN
# ...          ...     ...    ...   ...
# 1455         NaN     NaN    NaN   NaN
# 1456          85   13175   Pave   NaN
# 1457         NaN     NaN    NaN   NaN
# 1458          68    9717   Pave   NaN
# 1459         NaN     NaN    NaN   NaN
#
#      LotShape LandContour Utilities  \
# 0         Reg         Lvl    AllPub
# 1         Reg         Lvl    AllPub
# 2         IR1         Lvl    AllPub
# 3         IR1         Lvl    AllPub
# 4         IR1         Lvl    AllPub
# ...       ...         ...       ...
# 1455      Reg         Lvl    AllPub
# 1456      Reg         Lvl    AllPub
# 1457      Reg         Lvl    AllPub
# 1458      Reg         Lvl    AllPub
# 1459      Reg         Lvl    AllPub
#
#       ... PoolQC  Fence MiscFeature  \
# 0     ...    NaN    NaN         NaN
# 1     ...    NaN    NaN         NaN
# 2     ...    NaN    NaN         NaN
# 3     ...    NaN    NaN         NaN
# 4     ...    NaN    NaN         NaN
# ...   ...    ...    ...         ...
# 1455  ...    NaN    NaN         NaN
# 1456  ...    NaN  MnPrv         NaN
# 1457  ...    NaN  GdPrv        Shed
# 1458  ...    NaN    NaN         NaN
# 1459  ...    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold SaleType  \
# 0          0      2   2008       WD
# 1          0      5   2007       WD
# 2          0      9   2008       WD
# 3          0      2   2006       WD
# 4          0     12   2008       WD
# ...      ...    ...    ...      ...
# 1455       0      8   2007       WD
# 1456       0      2   2010       WD
# 1457    2500      5   2010       WD
# 1458       0      4   2010       WD
# 1459       0      6   2008       WD
#
#       SaleCondition  SalePrice   Id2
# 0            Normal     208500     2
# 1            Normal     181500     3
# 2            Normal     223500     4
# 3           Abnorml     140000     5
# 4            Normal     250000     6
# ...             ...        ...   ...
# 1455         Normal     175000  1457
# 1456         Normal     210000  1458
# 1457         Normal     266500  1459
# 1458         Normal     142125  1460
# 1459         Normal     147500  1461
#
# [1460 rows x 82 columns]

# %%
pd.set_option('display.max_rows', 10)
data
# Out:
#         Id MSSubClass MSZoning  \
# 0        1         60       RL
# 1        2        NaN      NaN
# 2        3         60       RL
# 3        4        NaN      NaN
# 4        5         60       RL
# ...    ...        ...      ...
# 1455  1456        NaN      NaN
# 1456  1457         20       RL
# 1457  1458        NaN      NaN
# 1458  1459         20       RL
# 1459  1460        NaN      NaN
#
#      LotFrontage LotArea Street Alley  \
# 0             65    8450   Pave   NaN
# 1            NaN     NaN    NaN   NaN
# 2             68   11250   Pave   NaN
# 3            NaN     NaN    NaN   NaN
# 4             84   14260   Pave   NaN
# ...          ...     ...    ...   ...
# 1455         NaN     NaN    NaN   NaN
# 1456          85   13175   Pave   NaN
# 1457         NaN     NaN    NaN   NaN
# 1458          68    9717   Pave   NaN
# 1459         NaN     NaN    NaN   NaN
#
#      LotShape LandContour Utilities  \
# 0         Reg         Lvl    AllPub
# 1         Reg         Lvl    AllPub
# 2         IR1         Lvl    AllPub
# 3         IR1         Lvl    AllPub
# 4         IR1         Lvl    AllPub
# ...       ...         ...       ...
# 1455      Reg         Lvl    AllPub
# 1456      Reg         Lvl    AllPub
# 1457      Reg         Lvl    AllPub
# 1458      Reg         Lvl    AllPub
# 1459      Reg         Lvl    AllPub
#
#       ... PoolQC  Fence MiscFeature  \
# 0     ...    NaN    NaN         NaN
# 1     ...    NaN    NaN         NaN
# 2     ...    NaN    NaN         NaN
# 3     ...    NaN    NaN         NaN
# 4     ...    NaN    NaN         NaN
# ...   ...    ...    ...         ...
# 1455  ...    NaN    NaN         NaN
# 1456  ...    NaN  MnPrv         NaN
# 1457  ...    NaN  GdPrv        Shed
# 1458  ...    NaN    NaN         NaN
# 1459  ...    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold SaleType  \
# 0          0      2   2008       WD
# 1          0      5   2007       WD
# 2          0      9   2008       WD
# 3          0      2   2006       WD
# 4          0     12   2008       WD
# ...      ...    ...    ...      ...
# 1455       0      8   2007       WD
# 1456       0      2   2010       WD
# 1457    2500      5   2010       WD
# 1458       0      4   2010       WD
# 1459       0      6   2008       WD
#
#       SaleCondition  SalePrice   Id2
# 0            Normal     208500     2
# 1            Normal     181500     3
# 2            Normal     223500     4
# 3           Abnorml     140000     5
# 4            Normal     250000     6
# ...             ...        ...   ...
# 1455         Normal     175000  1457
# 1456         Normal     210000  1458
# 1457         Normal     266500  1459
# 1458         Normal     142125  1460
# 1459         Normal     147500  1461
#
# [1460 rows x 82 columns]

# %%
df1 = data.loc[:,'Id':'Alley'][:6]
df2 = data.loc[:,'Id':'Alley'][6:10]

pd.concat([df1,df2], axis = 0,ignore_index=True)
# Out:
#    Id MSSubClass MSZoning LotFrontage  \
# 0   1         60       RL          65
# 1   2        NaN      NaN         NaN
# 2   3         60       RL          68
# 3   4        NaN      NaN         NaN
# 4   5         60       RL          84
# 5   6        NaN      NaN         NaN
# 6   7         20       RL          75
# 7   8        NaN      NaN         NaN
# 8   9         50       RM          51
# 9  10        NaN      NaN         NaN
#
#   LotArea Street Alley
# 0    8450   Pave   NaN
# 1     NaN    NaN   NaN
# 2   11250   Pave   NaN
# 3     NaN    NaN   NaN
# 4   14260   Pave   NaN
# 5     NaN    NaN   NaN
# 6   10084   Pave   NaN
# 7     NaN    NaN   NaN
# 8    6120   Pave   NaN
# 9     NaN    NaN   NaN

# %%
df11 = df1.loc[:,'Id':'MSZoning']
df12 = df1.loc[:,['Id','LotArea']]

# %%
pd.merge(df11,df12,how = 'inner', on ='Id',indicator=True, validate="one_to_one")#.dtypes ## Outer, inner, left, right
# Out:
#    Id MSSubClass MSZoning LotArea  \
# 0   1         60       RL    8450
# 1   2        NaN      NaN     NaN
# 2   3         60       RL   11250
# 3   4        NaN      NaN     NaN
# 4   5         60       RL   14260
# 5   6        NaN      NaN     NaN
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both
# 5   both

# %% [markdown]
# ### Pivoting dataset

# %%
df = pd.DataFrame({'Name' : ['Abhishek','Abhishek','Abhishek', 'Ritika','Ritika', 'Ritika'],
                  'subject': ['English','Math','Science', 'English', 'Math', 'Science'],
                  'marks': ['8','6','9', '10', '9', '9']})
df.pivot(index = 'Name',columns='subject', values='marks')
# Out:
# subject  English Math Science
# Name
# Abhishek       8    6       9
# Ritika        10    9       9

# %%
data['MSSubClass']
# Out:
# 0        60
# 1       NaN
# 2        60
# 3       NaN
# 4        60
#        ...
# 1455    NaN
# 1456     20
# 1457    NaN
# 1458     20
# 1459    NaN
# Name: MSSubClass, Length: 1460, dtype: object

# %%
data['MSSubClass'] == np.nan
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: MSSubClass, Length: 1460, dtype: bool

# %% [markdown]
# ### isna, notna, np.nan, fillna, df.fillna(method='pad', limit=1)
#
# df.replace('.', np.nan)

# %%
data.replace('NaN', np.nan)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1455   NaN
# 1456   NaN
# 1457   NaN
# 1458   NaN
# 1459   NaN
# Name: MSSubClass, Length: 1460, dtype: float64

# %%
data.describe() #statistical summary
# Out:
#                 Id  MSSubClass  \
# count  1460.000000         0.0
# mean    730.500000         NaN
# std     421.610009         NaN
# min       1.000000         NaN
# 25%     365.750000         NaN
# 50%     730.500000         NaN
# 75%    1095.250000         NaN
# max    1460.000000         NaN
#
#        OverallQual  OverallCond  \
# count  1460.000000  1460.000000
# mean      6.099315     5.575342
# std       1.382997     1.112799
# min       1.000000     1.000000
# 25%       5.000000     5.000000
# 50%       6.000000     5.000000
# 75%       7.000000     6.000000
# max      10.000000     9.000000
#
#          YearBuilt  YearRemodAdd  \
# count  1460.000000   1460.000000
# mean   1971.267808   1984.865753
# std      30.202904     20.645407
# min    1872.000000   1950.000000
# 25%    1954.000000   1967.000000
# 50%    1973.000000   1994.000000
# 75%    2000.000000   2004.000000
# max    2010.000000   2010.000000
#
#         MasVnrArea   BsmtFinSF1  \
# count  1452.000000  1460.000000
# mean    103.685262   443.639726
# std     181.066207   456.098091
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000   383.500000
# 75%     166.000000   712.250000
# max    1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  ...  \
# count  1460.000000  1460.000000  ...
# mean     46.549315   567.240411  ...
# std     161.319273   441.866955  ...
# min       0.000000     0.000000  ...
# 25%       0.000000   223.000000  ...
# 50%       0.000000   477.500000  ...
# 75%       0.000000   808.000000  ...
# max    1474.000000  2336.000000  ...
#
#        OpenPorchSF  EnclosedPorch  \
# count  1460.000000    1460.000000
# mean     46.660274      21.954110
# std      66.256028      61.119149
# min       0.000000       0.000000
# 25%       0.000000       0.000000
# 50%      25.000000       0.000000
# 75%      68.000000       0.000000
# max     547.000000     552.000000
#
#          3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000
# mean      3.409589    15.060959
# std      29.317331    55.757415
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max     508.000000   480.000000
#
#           PoolArea       MiscVal  \
# count  1460.000000   1460.000000
# mean      2.758904     43.489041
# std      40.177307    496.123024
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max     738.000000  15500.000000
#
#             MoSold       YrSold  \
# count  1460.000000  1460.000000
# mean      6.321918  2007.815753
# std       2.703626     1.328095
# min       1.000000  2006.000000
# 25%       5.000000  2007.000000
# 50%       6.000000  2008.000000
# 75%       8.000000  2009.000000
# max      12.000000  2010.000000
#
#            SalePrice          Id2
# count    1460.000000  1460.000000
# mean   180921.195890   731.500000
# std     79442.502883   421.610009
# min     34900.000000     2.000000
# 25%    129975.000000   366.750000
# 50%    163000.000000   731.500000
# 75%    214000.000000  1096.250000
# max    755000.000000  1461.000000
#
# [8 rows x 37 columns]

# %%
#data.info()
data.to_csv("dingdong.csv", index= False)

# %%
data['MSSubClass'].fillna(0, inplace = True)
data
# Out:
#         Id  MSSubClass MSZoning  \
# 0        1         0.0       RL
# 1        2         0.0      NaN
# 2        3         0.0       RL
# 3        4         0.0      NaN
# 4        5         0.0       RL
# ...    ...         ...      ...
# 1455  1456         0.0      NaN
# 1456  1457         0.0       RL
# 1457  1458         0.0      NaN
# 1458  1459         0.0       RL
# 1459  1460         0.0      NaN
#
#      LotFrontage LotArea Street Alley  \
# 0             65    8450   Pave   NaN
# 1            NaN     NaN    NaN   NaN
# 2             68   11250   Pave   NaN
# 3            NaN     NaN    NaN   NaN
# 4             84   14260   Pave   NaN
# ...          ...     ...    ...   ...
# 1455         NaN     NaN    NaN   NaN
# 1456          85   13175   Pave   NaN
# 1457         NaN     NaN    NaN   NaN
# 1458          68    9717   Pave   NaN
# 1459         NaN     NaN    NaN   NaN
#
#      LotShape LandContour Utilities  \
# 0         Reg         Lvl    AllPub
# 1         Reg         Lvl    AllPub
# 2         IR1         Lvl    AllPub
# 3         IR1         Lvl    AllPub
# 4         IR1         Lvl    AllPub
# ...       ...         ...       ...
# 1455      Reg         Lvl    AllPub
# 1456      Reg         Lvl    AllPub
# 1457      Reg         Lvl    AllPub
# 1458      Reg         Lvl    AllPub
# 1459      Reg         Lvl    AllPub
#
#       ... PoolQC  Fence MiscFeature  \
# 0     ...    NaN    NaN         NaN
# 1     ...    NaN    NaN         NaN
# 2     ...    NaN    NaN         NaN
# 3     ...    NaN    NaN         NaN
# 4     ...    NaN    NaN         NaN
# ...   ...    ...    ...         ...
# 1455  ...    NaN    NaN         NaN
# 1456  ...    NaN  MnPrv         NaN
# 1457  ...    NaN  GdPrv        Shed
# 1458  ...    NaN    NaN         NaN
# 1459  ...    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold SaleType  \
# 0          0      2   2008       WD
# 1          0      5   2007       WD
# 2          0      9   2008       WD
# 3          0      2   2006       WD
# 4          0     12   2008       WD
# ...      ...    ...    ...      ...
# 1455       0      8   2007       WD
# 1456       0      2   2010       WD
# 1457    2500      5   2010       WD
# 1458       0      4   2010       WD
# 1459       0      6   2008       WD
#
#       SaleCondition  SalePrice   Id2
# 0            Normal     208500     2
# 1            Normal     181500     3
# 2            Normal     223500     4
# 3           Abnorml     140000     5
# 4            Normal     250000     6
# ...             ...        ...   ...
# 1455         Normal     175000  1457
# 1456         Normal     210000  1458
# 1457         Normal     266500  1459
# 1458         Normal     142125  1460
# 1459         Normal     147500  1461
#
# [1460 rows x 82 columns]

# %%
data['new'] = 1
data.columns
data.column.values
# Out:
# array(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars',
#        'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature',
#        'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition',
#        'SalePrice', 'Id2', 'new'], dtype=object)

# %%
data.reset_index(drop = True, inplace = True)

# %%
data.drop(['new'],axis =1)
# Out:
#         Id  MSSubClass MSZoning  \
# 0        1         0.0       RL
# 1        2         0.0      NaN
# 2        3         0.0       RL
# 3        4         0.0      NaN
# 4        5         0.0       RL
# ...    ...         ...      ...
# 1455  1456         0.0      NaN
# 1456  1457         0.0       RL
# 1457  1458         0.0      NaN
# 1458  1459         0.0       RL
# 1459  1460         0.0      NaN
#
#      LotFrontage LotArea Street Alley  \
# 0             65    8450   Pave   NaN
# 1            NaN     NaN    NaN   NaN
# 2             68   11250   Pave   NaN
# 3            NaN     NaN    NaN   NaN
# 4             84   14260   Pave   NaN
# ...          ...     ...    ...   ...
# 1455         NaN     NaN    NaN   NaN
# 1456          85   13175   Pave   NaN
# 1457         NaN     NaN    NaN   NaN
# 1458          68    9717   Pave   NaN
# 1459         NaN     NaN    NaN   NaN
#
#      LotShape LandContour Utilities  \
# 0         Reg         Lvl    AllPub
# 1         Reg         Lvl    AllPub
# 2         IR1         Lvl    AllPub
# 3         IR1         Lvl    AllPub
# 4         IR1         Lvl    AllPub
# ...       ...         ...       ...
# 1455      Reg         Lvl    AllPub
# 1456      Reg         Lvl    AllPub
# 1457      Reg         Lvl    AllPub
# 1458      Reg         Lvl    AllPub
# 1459      Reg         Lvl    AllPub
#
#       ... PoolQC  Fence MiscFeature  \
# 0     ...    NaN    NaN         NaN
# 1     ...    NaN    NaN         NaN
# 2     ...    NaN    NaN         NaN
# 3     ...    NaN    NaN         NaN
# 4     ...    NaN    NaN         NaN
# ...   ...    ...    ...         ...
# 1455  ...    NaN    NaN         NaN
# 1456  ...    NaN  MnPrv         NaN
# 1457  ...    NaN  GdPrv        Shed
# 1458  ...    NaN    NaN         NaN
# 1459  ...    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold SaleType  \
# 0          0      2   2008       WD
# 1          0      5   2007       WD
# 2          0      9   2008       WD
# 3          0      2   2006       WD
# 4          0     12   2008       WD
# ...      ...    ...    ...      ...
# 1455       0      8   2007       WD
# 1456       0      2   2010       WD
# 1457    2500      5   2010       WD
# 1458       0      4   2010       WD
# 1459       0      6   2008       WD
#
#       SaleCondition  SalePrice   Id2
# 0            Normal     208500     2
# 1            Normal     181500     3
# 2            Normal     223500     4
# 3           Abnorml     140000     5
# 4            Normal     250000     6
# ...             ...        ...   ...
# 1455         Normal     175000  1457
# 1456         Normal     210000  1458
# 1457         Normal     266500  1459
# 1458         Normal     142125  1460
# 1459         Normal     147500  1461
#
# [1460 rows x 82 columns]

# %%
pd.Series(range(1,100))
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 94    95
# 95    96
# 96    97
# 97    98
# 98    99
# Length: 99, dtype: int64

# %%
from datetime import timedelta
d1 = pd.date_range('2020/1/1', periods =  10, freq ='7D') #D= regular days, B= business days
d1+timedelta(days =7)
# Out:
# DatetimeIndex(['2020-01-08',
#                '2020-01-15',
#                '2020-01-22',
#                '2020-01-29',
#                '2020-02-05',
#                '2020-02-12',
#                '2020-02-19',
#                '2020-02-26',
#                '2020-03-04',
#                '2020-03-11'],
#               dtype='datetime64[ns]', freq='W-WED')

# %% [markdown]
# ### group by

# %%
df = pd.DataFrame({'Name' : ['Abhishek','Abhishek','Abhishek', 'Ritika','Ritika', 'Ritika'],
                  'subject': ['English','Math','Science', 'English', 'Math', 'Science'],
                  'marks': [8,6,9,10,9,9]})
f = {'marks':['sum'],}
df.groupby(['Name']).agg(f)
# Out:
#          marks
#            sum
# Name
# Abhishek    23
# Ritika      28
